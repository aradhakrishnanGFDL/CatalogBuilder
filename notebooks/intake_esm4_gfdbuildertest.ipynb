# %% [markdown]
# Authors: A.Radhakrishnan

# %%
import xarray as xr
import intake
import intake_esm
import os
# Out:
# /nbhome/a1r/miniconda3/envs/intake/lib/python3.9/site-packages/fastprogress/fastprogress.py:102: UserWarning: Couldn't import ipywidgets properly, progress bar will use console behavior
#   warn("Couldn't import ipywidgets properly, progress bar will use console behavior")

# %%
col_url = "../catalogs/gfdl_eg/from_gfdlbuilder/gfdl_spec.json"

# %%
col = intake.open_esm_datastore(col_url)

# %%
#Examples to just search for what we want from the catalog
expname_filter = ['ESM4_1pctCO2_D1']
modeling_realm = 'atmos'
model_filter = 'ESM4'
variable_id_filter = "evap"
ens_filter = "r1i1p1f1"
frequency = "monthly"
chunk_freq = "5yr" #assuming we have 10 yr also, this will give unique ones

# %%
cat = col.search(experiment_id=expname_filter,frequency=frequency,modeling_realm=modeling_realm,
                 source_id=model_filter,variable_id=variable_id_filter)

# %%
cat.df["path"][0]
# Out:
# '/archive/oar.gfdl.cmip6/ESM4/DECK/ESM4_1pctCO2_D1/gfdl.ncrc4-intel16-prod-openmp/pp/atmos/ts/monthly/5yr/atmos.000101-000512.evap.nc'

# %%
#file="/archive/oar.gfdl.cmip6/ESM4/DECK/ESM4_1pctCO2_D1/gfdl.ncrc4-intel16-prod-openmp/pp/atmos/ts/monthly/5yr/atmos.013101-013512.z_Ri_025.nc"
#for simple dmget usage, just use this !dmget {file}
#use following to wrap the dmget call for each path in the catalog

def dmgetmagic(x):
    cmd = 'dmget %s'% str(x) 
    return os.system(cmd)

# %%
dmstatus = cat.df["path"].apply(dmgetmagic)

# %%
len(cat.df)
# Out:
# 30

# %%
dset_dict = cat.to_dataset_dict(cdf_kwargs={'chunks': {'time':60}, 'decode_times': False})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'source_id.experiment_id.frequency.modeling_realm.variable_id.chunk_freq'
# █

# %%
for k in dset_dict.keys(): 
    print(k)
# Out:
# ESM4.ESM4_1pctCO2_D1.monthly.atmos.evap.5yr

# %%
dset_dict["ESM4.ESM4_1pctCO2_D1.monthly.atmos.evap.5yr"]
# Out:
# <xarray.Dataset>
# Dimensions:     (bnds: 2, lat: 180, lon: 288, time: 1800)
# Coordinates:
#   * bnds        (bnds) float64 1.0 2.0
#   * lat         (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon         (lon) float64 0.625 1.875 3.125 4.375 ... 356.9 358.1 359.4
#   * time        (time) float64 15.5 45.0 74.5 ... 4.92e+04 4.923e+04 4.926e+04
# Data variables:
#     average_DT  (time) float64 dask.array<chunksize=(60,), meta=np.ndarray>
#     average_T1  (time) float64 dask.array<chunksize=(60,), meta=np.ndarray>
#     average_T2  (time) float64 dask.array<chunksize=(60,), meta=np.ndarray>
#     evap        (time, lat, lon) float32 dask.array<chunksize=(60, 180, 288), meta=np.ndarray>
#     lat_bnds    (lat, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#     lon_bnds    (lon, bnds) float64 dask.array<chunksize=(288, 2), meta=np.ndarray>
#     time_bnds   (time, bnds) float64 dask.array<chunksize=(60, 2), meta=np.ndarray>
# Attributes:
# ...

# %% [markdown]
# # FIND DATASETS by VARIABLE

# %%
cat = col.search(variable_id="omega")
cat.df
# Out:
#    activity_id institution_id source_id    experiment_id frequency  \
# 0          dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 1          dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 2          dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 3          dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 4          dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 5          dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 6          dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 7          dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 8          dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 9          dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 10         dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 11         dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# 12         dev           GFDL      ESM4  ESM4_1pctCO2_D1   monthly
# ...

# %%
dset_dict_omega= cat.to_dataset_dict(cdf_kwargs={'chunks': {'time':60}, 'decode_times': False})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'source_id.experiment_id.frequency.modeling_realm.variable_id.chunk_freq'
# █

# %%
for k in dset_dict.keys(): 
    print(k)
# Out:
# ESM4.ESM4_1pctCO2_D1.monthly.atmos.omega.5yr

# %%
dset_dict_omega["ESM4.ESM4_1pctCO2_D1.monthly.atmos.omega.5yr"]
# Out:
# <xarray.Dataset>
# Dimensions:     (bnds: 2, lat: 180, level: 23, lon: 288, time: 1800)
# Coordinates:
#   * bnds        (bnds) float64 1.0 2.0
#   * lat         (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * level       (level) float32 1000.0 925.0 850.0 775.0 ... 5.0 3.0 2.0 1.0
#   * lon         (lon) float64 0.625 1.875 3.125 4.375 ... 356.9 358.1 359.4
#   * time        (time) float64 4.199e+04 4.202e+04 ... 4.923e+04 4.926e+04
# Data variables:
#     average_DT  (time) float64 dask.array<chunksize=(60,), meta=np.ndarray>
#     average_T1  (time) float64 dask.array<chunksize=(60,), meta=np.ndarray>
#     average_T2  (time) float64 dask.array<chunksize=(60,), meta=np.ndarray>
#     lat_bnds    (lat, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#     lon_bnds    (lon, bnds) float64 dask.array<chunksize=(288, 2), meta=np.ndarray>
#     omega       (time, level, lat, lon) float32 dask.array<chunksize=(60, 23, 180, 288), meta=np.ndarray>
# ...

# %%
ds_omega = dset_dict_omega["ESM4.ESM4_1pctCO2_D1.monthly.atmos.omega.5yr"]

# %%
ds_omega
# Out:
# <xarray.Dataset>
# Dimensions:     (bnds: 2, lat: 180, level: 23, lon: 288, time: 1800)
# Coordinates:
#   * bnds        (bnds) float64 1.0 2.0
#   * lat         (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * level       (level) float32 1000.0 925.0 850.0 775.0 ... 5.0 3.0 2.0 1.0
#   * lon         (lon) float64 0.625 1.875 3.125 4.375 ... 356.9 358.1 359.4
#   * time        (time) float64 4.199e+04 4.202e+04 ... 4.923e+04 4.926e+04
# Data variables:
#     average_DT  (time) float64 dask.array<chunksize=(60,), meta=np.ndarray>
#     average_T1  (time) float64 dask.array<chunksize=(60,), meta=np.ndarray>
#     average_T2  (time) float64 dask.array<chunksize=(60,), meta=np.ndarray>
#     lat_bnds    (lat, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#     lon_bnds    (lon, bnds) float64 dask.array<chunksize=(288, 2), meta=np.ndarray>
#     omega       (time, level, lat, lon) float32 dask.array<chunksize=(60, 23, 180, 288), meta=np.ndarray>
# ...

# %%
da_omega = ds_omega.omega

# %%
da_omega.mean(dim='time')
# Out:
# <xarray.DataArray 'omega' (level: 23, lat: 180, lon: 288)>
# dask.array<mean_agg-aggregate, shape=(23, 180, 288), dtype=float32, chunksize=(23, 180, 288), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * level    (level) float32 1000.0 925.0 850.0 775.0 700.0 ... 5.0 3.0 2.0 1.0
#   * lon      (lon) float64 0.625 1.875 3.125 4.375 ... 355.6 356.9 358.1 359.4

# %% [markdown]
# # SEARCH FOR VARIABLES BY REALM (component yeah)

# %%
cat = col.search(modeling_realm="atmos")
cat.df
